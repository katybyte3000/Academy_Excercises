# %% [markdown]
# ## Epic 1: The 5 steps of Data Analysis

# %% [markdown]
# 1.Ask the qight Questions

# %% [markdown]
# 2.Data Wrangling

# %% [markdown]
# 3.Exploratory Data Analysis (EDA)

# %% [markdown]
# 4.Conclusion

# %% [markdown]
# 5.Communication Resuts

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ## Link:https://www.data-science-architect.de/selektieren-von-daten-in-dataframes/

# %%
import pandas as pd
import numpy as np

movies_df = pd.read_csv("movies_2.csv" ) # Gathering data
movies_df.head()
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %% [markdown]
# ### Shape
# a)the number of rows and columns present in the data set (i.e. the shape of the dataframe)

# %%
movies_df.shape
print("Die Tabelle hat", movies_df.shape[0],"Zeilen und ", movies_df.shape[1], "Spalten")
print(f"{"Die Tabelle hat"} {movies_df.shape[0]} {"Zeilen(rows) und "}{movies_df.shape[1]} {"Spalten(colums) "}")
# Out:
# Die Tabelle hat 616 Zeilen und  11 Spalten
# Die Tabelle hat 616 Zeilen(rows) und 11 Spalten(colums)

# %% [markdown]
# ### Info auslesen

# %%
movies_df.info
# Out:
# <bound method DataFrame.info of      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %% [markdown]
# ### Datentypen ermitteln mit dtype

# %%
movies_df.dtypes
# Out:
# MovieID           int64
# Title            object
# MPAA Rating      object
# Budget          float64
# Gross           float64
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# Summary          object
# dtype: object

# %%
movies_df.isna()
print(movies_df.isna())
#  Alle Spalten mit fehlenden Daten finden
#https://www.python4data.science/de/latest/clean-prep/nulls.html

incomplete_columns = list(movies_df.columns[movies_df.isnull().any()])
print(incomplete_columns)

for col in incomplete_columns:
    num_missing = movies_df[movies_df[col].isnull() == True].shape[0]
    print("number missing for column {}: {}".format(col, num_missing))

print(incomplete_columns)
# Out:
#      MovieID  Title  MPAA Rating  Budget  Gross  Release Date  Genre  Runtime  \
# 0      False  False        False   False  False         False  False    False
# 1      False  False        False   False  False         False  False    False
# 2      False  False        False   False  False         False  False    False
# 3      False  False        False   False  False         False  False    False
# 4      False  False        False   False  False         False  False    False
# ..       ...    ...          ...     ...    ...           ...    ...      ...
# 611    False  False        False   False  False         False  False    False
# 612    False  False        False   False  False         False  False    False
# 613    False  False        False   False  False         False  False    False
# 614    False  False        False   False  False         False  False    False
# 615    False   True         True    True   True          True   True     True
#
# ...

# %%
#movies_df[:5] #zeigt die ersten 5 Zeilen an
#movies_df.iloc[[1,2,3],[0,3]]
movies_df.loc[0:6]
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
# 5        6                  Uncle Buck          PG  15000000.0   79258538.0
# 6        7     When Harry Met Sally...           R  16000000.0   92800000.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
# ...

# %%
movies_df = pd.read_csv("movies_2.csv",nrows=0, header=0 ) # Gathering data erste Zeile


movies_df = pd.read_csv("movies_2.csv" )
# print(movies_df.head(5)) #auch die ersten 5 Zeilen
# movies_df.head()#auch die ersten 5 Zeilen
movies_df.tail()
movies_df.head()
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %% [markdown]
# ## NAN Werte ermitteln (schlechte Variante)

# %%
#movies_dfnew = movies_df.drop("Summary", axis=1)

# beispiel für löschen ohne neue Variable:movies_df.drop("Summary", axis=1, inplace=True)
##print(movies_dfnew)
#movies_dfnew.head()

# %% [markdown]
# ## Wann sollte man ein neues Dataframe erstellen?
#
# Wenn du den originalen DataFrame ändern möchtest, ohne eine neue Variable zu erstellen, verwende > inplace=True.
# Wenn du den originalen DataFrame beibehalten möchtest,
# aber die gelöschte Spalte in einem neuen DataFrame haben willst,
# kannst du einfach die drop()-Methode ohne inplace=True verwenden und das Ergebnis
# in einer neuen Variable speichern.

# %% [markdown]
# ## The ooriginal Dataframe without the Summary

# %%
movies_df.drop("Summary", axis=1, inplace=True)
movies_df.head()
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0

# %% [markdown]
# ## Standardize
#
# Our duty is not only to recognize the typos, but to also standardize the formatting of the values. For strings, make sure all values are either in lower or upper case. For numerical values, make sure all values have a certain measurement unit. Height, for example, can be in meters and centimeters, or feet and inches.

# %% [markdown]
# Task: use the rename method to change all column names to lowercase, and replace spaces with underscores if the name is made up of more than one word.

# %%
#movies_df.str.lower()
movies_df.head()
print(movies_df.columns)
#movies_df.iloc[0] #
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5336\3316407605.py in ?()
# ----> 1 movies_df.str.lower()
#       2 movies_df.head()
#       3 print(movies_df.columns)
#       4 #movies_df.iloc[0] #
#
# c:\Users\cumdi\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %% [markdown]
# movies_df["MovieID"]

# %% [markdown]
# ## Kleiner machen und umbennenen - rename

# %%
##print(movies_df.columns)  
#movies_df.dtypes

# if movies_df.columns  == movies_df.dtypes.object:
   #  movies_df.str.lower(movies_df)
# else:
    # pass

# movies_df["Title"] = movies_df["Title"].str.lower() # hat den inhalt in der Spalte kleine rgemacht
#movies_df.head()
movies_df.columns = movies_df.columns.str.lower()
movies_df.head()

#index für bestimmte Kategorie
#for index, row in movies_df.iterrows():
    #print(index,row["title"])

#for index, row in movies_df.iterrows():
    #print(index,row["rating"])

movies_df.rename(columns={'mpaa rating':'mpaa_rating'})
movies_df.rename(columns={'release date':'release_date'})

movies_df.head()
# Out:
#    movieid                       title mpaa rating      budget        gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   release date    genre  runtime  rating  rating count
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0

# %% [markdown]
# ## Drop
#
# If the missing values in a column rarely happen and occur at random, then the easiest and most forward solution is to drop observations (rows) that have missing values. If most of the column's values are missing, and occur at random, then a typical decision is to drop the whole column. This is particularly useful when doing statistical analysis, since filling in the missing values may yield unexpected or biased results.
#
# Task: Get rid of the last row, the one containing NaN for each column (use drop() method and row index)

# %% [markdown]
# LINK: https://www.geeksforgeeks.org/how-to-drop-rows-in-pandas-dataframe-by-index-labels/

# %% [markdown]
# #movies_df.drop(movies_df.columns[-1], axis=1, inplace=True) #flasch löscht eine komplette Spalte von hinten

# %%
# letzte Zeile anzeigen


#movies_df.iloc[-1:] #zeigt letzte Zeile an

#movies_df.drop(movies_df.tail(n).index,inplace=True) # drop last n rows  was ist n??? Funktioneirt nicht

#movies_df.drop(movies_df.columns[-1], axis=1, inplace=True) #flasch löscht eine komplette Spalte von hinten

# Löschen der letzten Zeile
#movies_df.drop(movies_df.index[-1], axis=0, inplace=True)


movies_df.iloc[-1:] #zeigt letzte Zeile an
# Out:
#      movieid title mpaa rating  budget  gross release date genre  runtime  \
# 615        0   NaN         NaN     NaN    NaN          NaN   NaN      NaN
#
#      rating  rating count
# 615     NaN           NaN

# %% [markdown]
# Fehlende Werte

# %% [markdown]
# movies_df [ "Bewertung" ] . isna ( ) . value_counts ( )
# ### Frage
#
# ### movies_df["rating"].value_counts() # das geht nicht aber warum??? War so in emelys script

# %%
#fehlerspalte = movies_df["Bewertung"].isna().svalue_counts()
#print("Anzahl der Nanwerte in der Kategorie Rating ist: ",fehlerspalte)

# %% [markdown]
# ## nach diesem Code (unten) verschwindet der DataFrame - Frage warum

# %%
#movies_df = movies_df[movies_df["rating"].isna()] # dieser code löscht alles
##print(movies_df)
##movies_df = movies_df[movies_df["rating"].value_counts()]
##print(movies_df)
## movies_df["rating"].value_counts() # das geht nicht aber warum???
movies_df.head()
# Out:
#    movieid                       title mpaa rating      budget        gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   release date    genre  runtime  rating  rating count
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0

# %% [markdown]
# # Calculate the median of Col1, Col2, Col3
# df['Median'] = df[['Col1', 'Col2', 'Col3']].median(axis=1)

# %%
#movies_df["Median"] = movies_df["rating"].median(axis = 1)
#movies_df["Median"] = movies_df["rating"].median()
#median_rating = movies_df["rating"].median()
movies_df.head()
# median_rating = movies_df.fillna('rating',movies_df['rating'].median(), inplace=True)
#print(median_rating)

median_rating = movies_df['rating'].median()
movies_df['rating'].fillna(median_rating, inplace=True)

#movies_df.fillna({"rating":movies_df["rating"].median()},inplace=True)#Marcs Lösung
movies_df.tail()

# Löschen der letzten Zeile
#movies_df.drop(movies_df.index[-1], axis=0, inplace=True)
movies_df.tail()
# Out:
# C:\Users\cumdi\AppData\Local\Temp\ipykernel_5336\893878979.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   movies_df['rating'].fillna(median_rating, inplace=True)
#      movieid                                  title mpaa rating       budget  \
# 610      611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# ...

# %%
movies_df['budget'] = movies_df['budget'].fillna(0).astype(int)
movies_df['gross'] = movies_df['gross'].fillna(0).astype(int)

#movies_df['budget'] = movies_df['budget'].astype(int)
movies_df.tail()
movies_df.dtypes
# Out:
# movieid           int64
# title            object
# mpaa rating      object
# budget            int32
# gross             int32
# release date     object
# genre            object
# runtime         float64
# rating          float64
# rating count    float64
# dtype: object

# %% [markdown]
# ## Date to daytime

# %% [markdown]
# ## Vergleiche und Filter

# %%
#movies_df[((movies_df["genre"] == "Action") &  (movies_df["rating"] > 6)]
          
movies_df[(movies_df["runtime"] > 100) & (movies_df["gross"] >296000000)]
movies_df
# Out:
#      movieid                                  title mpaa rating     budget  \
# 0          1                     Look Who's Talking       PG-13    7500000
# 1          2                     Driving Miss Daisy          PG    7500000
# 2          3                         Turner & Hooch          PG   13000000
# 3          4             Born on the Fourth of July           R   14000000
# 4          5                        Field of Dreams          PG   15000000
# ..       ...                                    ...         ...        ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000
# 611      612                            Toy Story 4           G  200000000
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613      614                          The Lion King          PG  250000000
# 614      615                      Avengers: Endgame       PG-13  356000000
#
# ...

# %% [markdown]
# Diskussion letzte Aufgabe: wenn mehr Leute den Film bewertet haben ist der Film auch besser = Wahrscheinlich
