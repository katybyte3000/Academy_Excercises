# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# D:\Python Bootcamp\Modul 1\Project_02\windedata\winequality-red.csv
red_wine = pd.read_csv(r"D:\Python Bootcamp\Modul 1\Project_02\windedata\winequality-red.csv", sep =";")
red_wine.tail(10)
#C:\Users\cumdi\Desktop\Bootcamp Visual Studio\Modul 1\Project_02\windedata\winequality-red.csv
# SEP-Argument seperiert die Daten, hier ist es  mit einem Semicolon

white_wine = pd.read_csv(r"D:\Python Bootcamp\Modul 1\Project_02\windedata\winequality-white.csv", sep =";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 import seaborn as sns
#       5 # D:\Python Bootcamp\Modul 1\Project_02\windedata\winequality-red.csv
# ----> 6 red_wine = pd.read_csv(r"D:\Python Bootcamp\Modul 1\Project_02\windedata\winequality-red.csv", sep =";")
#       7 red_wine.tail(10)
#       8 #C:\Users\cumdi\Desktop\Bootcamp Visual Studio\Modul 1\Project_02\windedata\winequality-red.csv
#       9 # SEP-Argument seperiert die Daten, hier ist es  mit einem Semicolon
#
# ...

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
corrdata = pd.DataFrame(red_wine)
print(corrdata.corr())
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
# cor = df.corr()
# cor_target = abs(cor["label"])
# relevant_features = cor_target[cor_target>0.05]
# df2 = df.loc[:, relevant_features.index]

# %%
red_wine.columns = red_wine.columns.str.replace( ' ','_') #replaced Leerzeichen mit Unterstrich
red_wine.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
white_wine.columns = red_wine.columns.str.replace( ' ','_') #replaced Leerzeichen mit Unterstrich
white_wine.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
red_wine.drop("citric_acid", axis=1).apply(lambda x: x.corr(red_wine.citric_acid))
# Out:
# fixed_acidity           0.671703
# volatile_acidity       -0.552496
# residual_sugar          0.143577
# chlorides               0.203823
# free_sulfur_dioxide    -0.060978
# total_sulfur_dioxide    0.035533
# density                 0.364947
# pH                     -0.541904
# sulphates               0.312770
# alcohol                 0.109903
# quality                 0.226373
# dtype: float64

# %%
red_wine.drop("citric_acid", axis=1).apply(lambda x: x.corr(red_wine.free_sulfur_dioxide))
# Out:
# fixed_acidity          -0.153794
# volatile_acidity       -0.010504
# residual_sugar          0.187049
# chlorides               0.005562
# free_sulfur_dioxide     1.000000
# total_sulfur_dioxide    0.667666
# density                -0.021946
# pH                      0.070377
# sulphates               0.051658
# alcohol                -0.069408
# quality                -0.050656
# dtype: float64

# %% [markdown]
# ### Beispiel für das auwählen nur bestimmter Spalten für die Heatmap

# %%
red_wine.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
heatwine = pd.DataFrame(red_wine)


# Wähle nur die Spalten aus, die du in der Heatmap sehen möchtest
selected_columns = ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar']  # Beispiel: Du möchtest nur Spalten A, B, C und D verwenden

# Berechne die Korrelation nur für diese ausgewählten Spalten
korrelation = heatwine[selected_columns].corr()

# Erstelle die Heatmap
sns.heatmap(korrelation, annot=True, cmap='Purples')

# Zeige die Heatmap an
plt.show()

# %% [markdown]
# # Sprint 2

# %%
red_wine.hist(bins=10, color='red', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))
plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

white_wine.hist(bins=10, color='yellow', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))
plt.suptitle('White Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)
# Out:
# Text(0.65, 1.25, 'White Wine Univariate Plots')

# %%
red_wine.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
sns.histplot(red_wine, x="residual_sugar", binwidth=1 )
# Out:
# <Axes: xlabel='residual_sugar', ylabel='Count'>

# %%
sns.histplot(white_wine, x="residual_sugar", binwidth=1 )
# Out:
# <Axes: xlabel='residual_sugar', ylabel='Count'>

# %% [markdown]
# histogram

# %%
#plot 1:
bins = [1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6,7,7.5,8,8.5]
b = red_wine['residual_sugar']

plt.title('Sugar in Red Wine')
plt.subplot(1, 2, 1)
plt.hist(b,bins = bins)

#plot 2:
a = white_wine['residual_sugar']

#plt.title('Zucker im Weißwein')
plt.subplot(1, 2, 2)
plt.hist(a, bins = bins)

plt.show()
