# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

red_wine = pd.read_csv("winequality-red.csv", sep =";")
red_wine.tail(10)
#C:\Users\cumdi\Desktop\Bootcamp Visual Studio\Modul 1\Project_02\windedata\winequality-red.csv
# SEP-Argument seperiert die Daten, hier ist es  mit einem Semicolon

white_wine = pd.read_csv("winequality-white.csv", sep =";")

# %%
print("Hallo FInn wie gehts?")
# Out:
# Hallo FInn wie gehts?

# %%
red_wine.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
white_wine.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ### Shape messen

# %%
print(f"{"Shapefunktion: Wir haben " } {white_wine.shape[0]} {" Zeilen und "}{white_wine.shape[1]} {" Spalten"}")
#print(f"Standardabweichung: {standardabweichung:.2f}")
# Out:
# Shapefunktion: Wir haben  4898  Zeilen und 12  Spalten

# %% [markdown]
# ### Werte prüfen auf Fehlstellen & NAN Werte

# %%
#na_matrix = Weisswein.isna()

#print(na_matrix)
#anzahl der Nan Werte'
nan_count = white_wine.isna().sum().sum()

if nan_count == 0:
        print(f"Es gibt {nan_count} keine Fehler")
else:
        print(f"Es gibt {nan_count} Fehler")


        #print(f"Standardabweichung: {standardabweichung:.2f}")
# Out:
# Es gibt 0 keine Fehler

# %% [markdown]
# ### Describe

# %%
white_wine.describe
# Out:
# <bound method NDFrame.describe of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ### Let's now group our qualities into 3 categories: low, medium and high quality wines.

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into a categorical data type (specific to pandas) instead of a simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into a categorical data type (specific to pandas) instead of a simple string
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
red_wine.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
white_wine.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# #Combine both
# pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])

# %% [markdown]
# ###  Allgemeine  Werte schaubetrachten (mean, std, min)

# %%
redandwhite = pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
redandwhite.head(10)
# Out:
#       Red Wines Stats                                               \
#         fixed acidity volatile acidity  citric acid residual sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %% [markdown]
# ### Create a new Column mit Kategorie Weinsorte - winetype

# %% [markdown]
# ***Variante 1 - easy, fügt neue Kategorie am Ende ein***

# %%
#white_wine["wine_type"] = "white" #kreiiert eine neue Zeilte mit Weintyp
#white_wine.tail(10)

# %% [markdown]
# ***Variante 2 - fügt an bestimmter Stelle mit insert()***

# %%
white_wine.insert(0,"winetype","white")   #Variante 2: (Index, also wo,neueKatergory,werte)
white_wine.tail(10)
# Out:
#      winetype  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 4888    white            6.8             0.220         0.36            1.20
# 4889    white            4.9             0.235         0.27           11.75
# 4890    white            6.1             0.340         0.29            2.20
# 4891    white            5.7             0.210         0.32            0.90
# 4892    white            6.5             0.230         0.38            1.30
# 4893    white            6.2             0.210         0.29            1.60
# 4894    white            6.6             0.320         0.36            8.00
# 4895    white            6.5             0.240         0.19            1.20
# 4896    white            5.5             0.290         0.30            1.10
# 4897    white            6.0             0.210         0.38            0.80
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
red_wine.insert(0,"winetype","red")   #Variante 2: (Index, also wo,neueKatergory,werte)
red_wine.tail(10)
# Out:
#      winetype  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1589      red            6.6             0.725         0.20             7.8
# 1590      red            6.3             0.550         0.15             1.8
# 1591      red            5.4             0.740         0.09             1.7
# 1592      red            6.3             0.510         0.13             2.3
# 1593      red            6.8             0.620         0.08             1.9
# 1594      red            6.2             0.600         0.08             2.0
# 1595      red            5.9             0.550         0.10             2.2
# 1596      red            6.3             0.510         0.13             2.3
# 1597      red            5.9             0.645         0.12             2.0
# 1598      red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ***Variante 3 - assign Methode: gut für mehrere neue Colums***

# %%
#white_wine=white_wine.assign(Whitewine = True , Rotwein = False)
#white_wine.tail(10)

# %% [markdown]
# ## 2 Dataframes zusammenfügen

# %% [markdown]
# Methode-Stacking-alle Werte untereinander

# %%
allwine= pd.concat([red_wine,white_wine], ignore_index=True)
allwine.head(10)
# Out:
#   winetype  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0      red            7.4              0.70         0.00             1.9
# 1      red            7.8              0.88         0.00             2.6
# 2      red            7.8              0.76         0.04             2.3
# 3      red           11.2              0.28         0.56             1.9
# 4      red            7.4              0.70         0.00             1.9
# 5      red            7.4              0.66         0.00             1.8
# 6      red            7.9              0.60         0.06             1.6
# 7      red            7.3              0.65         0.00             1.2
# 8      red            7.8              0.58         0.02             2.0
# 9      red            7.5              0.50         0.36             6.1
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# ...

# %% [markdown]
# ## Datawrangling:Labelnames with underscores (Schreibweise korrigieren)

# %%
#movies_df.rename(columns={'mpaa rating':'mpaa_rating'}) #manuelle variante, bei vielen Werten umständlich
#movies_df.rename(columns={'release date':'release_date'})

# %%
#link: https://thetawise.ai/answers/convert-spaces-dashes-and-commas-in-the-column-names-to-underscore
allwine.columns = allwine.columns.str.replace( ' ','_') #replaced Leerzeichen mit Unterstrich
allwine.head(10)
# Out:
#   winetype  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0      red            7.4              0.70         0.00             1.9
# 1      red            7.8              0.88         0.00             2.6
# 2      red            7.8              0.76         0.04             2.3
# 3      red           11.2              0.28         0.56             1.9
# 4      red            7.4              0.70         0.00             1.9
# 5      red            7.4              0.66         0.00             1.8
# 6      red            7.9              0.60         0.06             1.6
# 7      red            7.3              0.65         0.00             1.2
# 8      red            7.8              0.58         0.02             2.0
# 9      red            7.5              0.50         0.36             6.1
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# ...

# %% [markdown]
# ### Pairplot allgemein mit Trennung in rot und Weißwein

# %%
#sns.pairplot(allwine)
# sns.pairplot(allwine[["size", "tip"]])
#plt.show()

# %%
#sns.pairplot(allwine ,  hue="winetype")
# sns.pairplot(allwine[["size", "tip"]])
#plt.show()

# %% [markdown]
# ## PIE CHARTS -  Kreisdiagramme

# %% [markdown]
# Aufgabe 1: The first plot you should do is a pie chart, showing the quantity of red wines compared to the quantity of white wines.

# %%
import matplotlib.pyplot as plt

# Create a dataframe with the data

data = {'Product': ['Red Wine', 'White Wine'], 'Anzahl': [len(red_wine["winetype"]), len(white_wine["winetype"])]}
winecolors= ['darkred', 'khaki']
df = pd.DataFrame(data)

# Plot the pie chart
section_out = [0,0.2]
plt.pie(df['Anzahl'], labels=df['Product'], colors=winecolors, shadow=3, explode=section_out)

plt.show()

# %% [markdown]
# ### Pie Chart

# %%
# Falscher Ansatz

redcount = len(red_wine["winetype"])
print(redcount)

whitecount = len(white_wine["winetype"])
print(whitecount)

allcount = whitecount + redcount
print(allcount)

labels = ['Rotwein', 'Weißwein']
sizes = [redcount, whitecount]
colors = ['r', 'y']

plt.figure(figsize=(7, 7))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors)

# Titel hinzufügen
plt.title('Vergleich der Anzahl der Zeilen in den DataFrames')

# Diagramm anzeigen
plt.show()

#Lösung ohne Rechnen

#yy = np.array([1599,4898])
#plt.pie(yy)
#plt.show()

#Probleme mit Lapels
# Out:
# 1599
# 4898
# 6497

# %% [markdown]
# ### Seaborn

# %%
sns.displot(white_wine['quality_label'])
sns.displot(red_wine['quality_label'])

# %% [markdown]
# ## Histplot - Verschiedene Variaten

# %%
#sns.set_style["darkgrid"] #funktioniert nicht
sns.set_style("whitegrid")
#sns.histplot(red_wine["quality_label"]) # Variate 01
sns.histplot(red_wine.quality_label, color='red', edgecolor='black'); # Variante 02

# %%
#sns.set_style("whitegrid")
#sns.histplot(red_wine["quality_label"]) # Variate 01

sns.histplot(white_wine.quality_label, color='blue', edgecolor='black'  , binwidth=20, alpha=0.4); # Variante 02
sns.histplot(red_wine.quality_label, color='green', edgecolor='black'  , binwidth=20, alpha=0.4); # Variante 02
plt.xlabel("Wine Quality")
plt.ylabel("Anzahl an Weinen")
# Out:
# Text(0, 0.5, 'Anzahl an Weinen')

# %% [markdown]
# Gedrehtes Histplot

# %%
sns.histplot(y = red_wine.quality_label, color='red', edgecolor='black', bins =20 ); # Variante 02

# %% [markdown]
# ### Compare Alcohol and Anzahl

# %%
allwine.head()

#sns.histplot(allwine.alcohol, color='blue', edgecolor='black'  ); # Variante 02

sns.histplot(allwine, x='alcohol' , hue='winetype', edgecolor='black')
plt.xlabel("Alkoholmenge")
plt.ylabel("Anzahl an Weinen")
plt.show()
#sns.histplot(red_wine.quality_label, color='green', edgecolor='black'  , binwidth=20, alpha=0.4); # Variante 02

# %% [markdown]
# ## Working with Pairplot

# %% [markdown]
# Compare 2 oder 3 Variables

# %%
#sns.pairplot(red_wine, vars=['alcohol','quality_label'])

sns.pairplot(allwine, vars=['alcohol','citric_acid'] , hue='winetype')
allwine.head()
# Out:
#   winetype  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0      red            7.4              0.70         0.00             1.9
# 1      red            7.8              0.88         0.00             2.6
# 2      red            7.8              0.76         0.04             2.3
# 3      red           11.2              0.28         0.56             1.9
# 4      red            7.4              0.70         0.00             1.9
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality quality_label
# 0       0.56      9.4        5           low
# ...

# %% [markdown]
# ### Alcohol vs Quality

# %%
sns.pairplot(allwine, vars=['alcohol','quality'] , hue='winetype')
#https://www.youtube.com/watch?v=uCgvlfIo9fg Styling of pairplote and interactive tool

# %% [markdown]
# ### Alkoholmenge - quantity of alcohol

# %%
allwine.head()

#sns.histplot(allwine.alcohol, color='blue', edgecolor='black'  ); # Variante 02
sns.color_palette("crest", as_cmap=True)

sns.histplot(allwine, x='alcohol', y='quality', palette='rocket', hue='winetype' ) # hue='winetype', palette='flare'
plt.xlabel("Alkoholmenge")
plt.ylabel("Anzahl an Weinen")
plt.show()

allwine.head()

#sns.histplot(allwine.alcohol, color='blue', edgecolor='black'  ); # Variante 02
# Out:
#   winetype  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0      red            7.4              0.70         0.00             1.9
# 1      red            7.8              0.88         0.00             2.6
# 2      red            7.8              0.76         0.04             2.3
# 3      red           11.2              0.28         0.56             1.9
# 4      red            7.4              0.70         0.00             1.9
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality quality_label
# 0       0.56      9.4        5           low
# ...

# %% [markdown]
# ### Displot

# %%
sns.displot(allwine['alcohol'], bins=80)

# %% [markdown]
# ## Sugar in Wine

# %% [markdown]
# ### New Category Sweetness

# %%
# create new column
allwine['sweetness'] = allwine['residual_sugar'].apply(lambda value: 'dry'
if value <= 9 else 'semidry'
if value <= 18 else 'sweet')

# transform into categorical type
allwine['sweetness'] = pd.Categorical(allwine['sweetness'], categories=['dry', 'semidry', 'sweet'])

# %%
allwine.head()
# Out:
#   winetype  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0      red            7.4              0.70         0.00             1.9
# 1      red            7.8              0.88         0.00             2.6
# 2      red            7.8              0.76         0.04             2.3
# 3      red           11.2              0.28         0.56             1.9
# 4      red            7.4              0.70         0.00             1.9
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality quality_label sweetness
# ...

# %%
allwine.head()

#sns.histplot(allwine.alcohol, color='blue', edgecolor='black'  ); # Variante 02

sns.histplot(allwine, x='quality' , hue='sweetness', edgecolor='black')
plt.xlabel("Alkoholmenge")
plt.ylabel("Anzahl an Weinen")
plt.show()

# %% [markdown]
# Sweetness Amount

# %%
import matplotlib.pyplot as plt

# Create a dataframe with the data

data = {'Product': ['Red Wine', 'White Wine'], 'Anzahl': [len(red_wine["winetype"]), len(white_wine["winetype"])]}
winecolors= ['red', 'beige']
df = pd.DataFrame(data)

# Plot the pie chart
section_out = [0,0.2]
plt.pie(df['Anzahl'], labels=df['Product'], colors=winecolors, shadow=3, explode=section_out)

plt.show()

# %%
sns.histplot(allwine.sweetness, color='blue', edgecolor='black' , alpha=0.4); # Variante 02
plt.xlabel("Sweetness")
plt.ylabel("Anzahl an Weinen")


plt.show()

# %%
sweetness_counts = allwine['sweetness'].value_counts()
print(sweetness_counts)
# Out:
# sweetness
# dry        5119
# semidry    1295
# sweet        83
# Name: count, dtype: int64

# %%
allwine.head()

#sns.histplot(allwine.alcohol, color='blue', edgecolor='black'  ); # Variante 02
sns.color_palette("crest", as_cmap=True)

sns.histplot(allwine, x='sweetness', y='quality', palette='rocket', hue='winetype' ) # hue='winetype', palette='flare'
plt.xlabel("Alkoholmenge")
plt.ylabel("Anzahl an Weinen")
plt.show()

allwine.head()
# Out:
#   winetype  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0      red            7.4              0.70         0.00             1.9
# 1      red            7.8              0.88         0.00             2.6
# 2      red            7.8              0.76         0.04             2.3
# 3      red           11.2              0.28         0.56             1.9
# 4      red            7.4              0.70         0.00             1.9
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality quality_label sweetness
# ...

# %%
#sns.pairplot(allwine, vars=['sweetness'] , hue='quality')
#allwine.head()

#sns.pairplot(allwine ,  hue="sweetness")

# %%
sns.pairplot(allwine, vars=['citric_acid'] , hue='sweetness', kind ='hist')

# %%
#sns.pairplot(allwine , hue='winetype', kind ='hist')

# %%
sns.pairplot(allwine, vars=['quality','pH'] , hue='sweetness')

# %%
#sns.boxplot(x=allwine["alcohol"])
sns.boxplot(x = 'quality_label', y = 'alcohol', data = red_wine)
# Out:
# <Axes: xlabel='quality_label', ylabel='alcohol'>

# %% [markdown]
# ### PH Wert Vergleich von Rot und Weißwein

# %%
#sns.boxplot(x = 'quality_label', y = 'pH', data = white_wine) 
sns.boxplot(x = 'quality_label', y = 'pH', data = allwine, hue = 'winetype', palette="rainbow")
# Out:
# <Axes: xlabel='quality_label', ylabel='pH'>

# %% [markdown]
# Wein weist einen pH-Wert zwischen 2,7 und 4,0 auf, wobei pH-Werte von 3,5 und höher schon kritisch sind. Der ideale pH-Wert für mikrobiologisch stabilen Wein liegt zwischen 2,9 und 3,9.

# %% [markdown]
# Weißweine weisen in der Regel einen niedrigeren pH-Wert auf und liegen im sauren Bereich mit einem pH-Wert von etwa 3 bis 3,5. Die meisten Rotweine haben einen pH-Wert zwischen 3,5 und über 4. Dieser Unterschied im pH-Wert trägt dazu bei, dass Weißweine als frischer und lebendiger wahrgenommen werden, während Rotweine eine etwas mildere Säure aufweisen.

# %% [markdown]
# Quelle:https://www.weinfreunde.de/magazin/weinwissen/saeuregehalt-im-wein-der-schluessel-zu-geschmack-und-qualitaet/#:~:text=Um%20den%20S%C3%A4uregehalt%20eines%20Weins,Skala%20von%200%20bis%2014.

# %% [markdown]
# ### Der Boxplot zeigt das es im mittleren Qualitätsbereich Bereich einige Ausreisser gibt wo der PH Wert schon uber dem kritischen 3,5 liegt

# %% [markdown]
# Im Wein gilt: Je niedriger der pH-Wert, umso höher die Weinsäure, umso stabiler der Wein
# Quelle:https://www.weinhalle.de/lexikon/ph-wert.html

# %% [markdown]
# ### Alkohol vs Qualität

# %%
sns.boxplot(y= 'alcohol', x= 'quality', data = allwine, palette="rainbow")
# Out:
# C:\Users\cumdi\AppData\Local\Temp\ipykernel_18964\2197234260.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y= 'alcohol', x= 'quality', data = allwine, palette="rainbow")
# <Axes: xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# ### Mehr Alkohol findet sich in den besseren Weinen

# %% [markdown]
# ## A View on fixed_acidity (Weinsäure)

# %% [markdown]
# Die Messung der Säure im Wein in Gramm pro Liter
# Eine weitere Möglichkeit, den Säuregehalt eines Weins zu bewerten, besteht darin, die Säure in Gramm pro Liter auszudrücken. Als Faustformel lässt sich gut merken, dass ein ***Weißwein, der mindestens sechs Gramm Säure pro Liter enthält als frisch zu bezeichnen*** ist. Riesling oder Champagner kann aber auch locker acht oder sogar neun Gramm Säure pro Liter enthalten.

# %%
allwine.head()

#topfive3 = movies_df.nlargest(5, "budget")[["title", "budget"]]
# Out:
#   winetype  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0      red            7.4              0.70         0.00             1.9
# 1      red            7.8              0.88         0.00             2.6
# 2      red            7.8              0.76         0.04             2.3
# 3      red           11.2              0.28         0.56             1.9
# 4      red            7.4              0.70         0.00             1.9
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality quality_label sweetness
# ...

# %%
mostacid = allwine.nlargest(15,"fixed_acidity")
mostacid[["fixed_acidity", "quality", "winetype"]]
# Out:
#       fixed_acidity  quality winetype
# 652            15.9        5      red
# 442            15.6        7      red
# 557            15.6        5      red
# 554            15.5        5      red
# 555            15.5        5      red
# 243            15.0        7      red
# 244            15.0        7      red
# 544            14.3        6      red
# 3125           14.2        6    white
# 374            14.0        6      red
# 347            13.8        6      red
# 381            13.7        6      red
# 391            13.7        6      red
# 353            13.5        5      red
# 328            13.4        6      red

# %% [markdown]
# ### Weinsäure Einfluss auf Farbe

# %% [markdown]
# ## volatile_acidity

# %%
sns.boxplot(y = 'volatile_acidity', data = allwine, hue = 'winetype', palette="rainbow")
# Out:
# <Axes: ylabel='volatile_acidity'>

# %%
meanacid = np.mean(allwine["fixed_acidity"])
print("Durschnittliche Weinsäue: " ,meanacid)
# Out:
# Durschnittliche Weinsäue:  7.215307064799139

# %% [markdown]
# ## fixed_acidity

# %%
sns.boxplot(y = 'fixed_acidity', data = allwine, hue = 'winetype', palette="rainbow")
# Out:
# <Axes: ylabel='fixed_acidity'>

# %% [markdown]
# Allerdings schwankt die Weinsäue auf natürliche Weiße, es kommt auf die Weinsorte an

# %% [markdown]
# ## Eindeutig: Bei Rotwein ist der antweil Fixed und fluid Acidy hoch
# ### diese Grafik noch schöner machen mit Titel und Achsen Text

# %%
sns.jointplot(data=allwine, x='volatile_acidity', y='quality', palette = 'rainbow', hue = 'winetype')

plt.show()

# %%
sns.kdeplot(data=allwine, x='volatile_acidity', hue='winetype', fill=True)
# Out:
# <Axes: xlabel='volatile_acidity', ylabel='Density'>

# %%
sns.jointplot(data=allwine, x='fixed_acidity', y='quality', palette = 'rainbow', hue = 'winetype')

plt.show()

# %%
sns.kdeplot(data=allwine, x='fixed_acidity', hue='winetype', fill=True)
# Out:
# <Axes: xlabel='fixed_acidity', ylabel='Density'>

# %% [markdown]
# ### Density

# %%
sns.kdeplot(data=allwine, x='density', hue='winetype', fill=True)
# Out:
# <Axes: xlabel='density', ylabel='Density'>

# %%
sns.boxplot(y = 'density', data = allwine, hue = 'winetype', palette="rainbow")
# Out:
# <Axes: ylabel='density'>

# %% [markdown]
# ## pH WERT

# %%
sns.jointplot(data=allwine, x='pH', y ='total_sulfur_dioxide', palette = 'rainbow', hue = 'winetype')

plt.show()

# %%
sns.kdeplot(allwine['pH'])
plt.title('Verteilung der pH-Werte')
plt.xlabel('pH-Wert')
plt.ylabel('Dichte')
plt.show()

# %%
sns.kdeplot(data=allwine, x='pH', hue='winetype', fill=True)
# Out:
# <Axes: xlabel='pH', ylabel='Density'>

# %% [markdown]
# ## Citrit Acid

# %%
sns.boxplot(y = 'citric_acid', data = allwine, hue = 'winetype', palette="rainbow")
# Out:
# <Axes: ylabel='citric_acid'>

# %%
sns.kdeplot(data=allwine, y='citric_acid', hue='winetype', fill=True)
# Out:
# <Axes: xlabel='Density', ylabel='citric_acid'>

# %%
sns.scatterplot(data=allwine, x="citric_acid", y="total_sulfur_dioxide", hue="winetype")
# Out:
# <Axes: xlabel='citric_acid', ylabel='total_sulfur_dioxide'>

# %%
sns.boxplot(y = 'citric_acid', data = allwine, hue = 'winetype', palette="rainbow")
# Out:
# <Axes: ylabel='citric_acid'>

# %%
sns.scatterplot(data=allwine, x="total_sulfur_dioxide", y="alcohol", hue="winetype")
# Out:
# <Axes: xlabel='total_sulfur_dioxide', ylabel='alcohol'>

# %% [markdown]
# Korrelationen

# %%
import pandas as pd

df = {
    "Array_1": [30, 70, 100],
    "Array_2": [65.1, 49.50, 30.7]
}

data = pd.DataFrame(df)

print(data.corr())
# Out:
#           Array_1   Array_2
# Array_1  1.000000 -0.990773
# Array_2 -0.990773  1.000000

# %%
allwine.tail()
# Out:
#      winetype  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 6492    white            6.2              0.21         0.29             1.6
# 6493    white            6.6              0.32         0.36             8.0
# 6494    white            6.5              0.24         0.19             1.2
# 6495    white            5.5              0.29         0.30             1.1
# 6496    white            6.0              0.21         0.38             0.8
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 6492      0.039                 24.0                  92.0  0.99114  3.27
# 6493      0.047                 57.0                 168.0  0.99490  3.15
# 6494      0.041                 30.0                 111.0  0.99254  2.99
# 6495      0.022                 20.0                 110.0  0.98869  3.34
# 6496      0.020                 22.0                  98.0  0.98941  3.26
#
#       sulphates  alcohol  quality quality_label sweetness
# ...

# %% [markdown]
# ### Anova Test

# %%
from scipy import stats

F, p = stats.f_oneway(
    allwine[allwine['sweetness'] == 'dry']['alcohol'],
    allwine[allwine['sweetness'] == 'semidry']['alcohol'],
    allwine[allwine['sweetness'] == 'sweet']['alcohol']
)
print('ANOVA test for mean alcohol levels across wine samples with different sugar')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different sugar
# F Statistic: 453.0407465907092 	p-value: 6.553355923075323e-185
