# %% [markdown]
# ## ***Summary of Sprint 4***

# %%
import pandas as pd
import numpy as np

movies_df = pd.read_csv("movies_2.csv" ) # Gathering data
movies_df.head(10)
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
# 5        6                  Uncle Buck          PG  15000000.0   79258538.0
# 6        7     When Harry Met Sally...           R  16000000.0   92800000.0
# 7        8          Dead Poets Society          PG  16400000.0  235860116.0
# 8        9                  Parenthood       PG-13  20000000.0  126297830.0
# 9       10             Lethal Weapon 2           R  25000000.0  227853986.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# ...

# %%
movies_df
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
#movies_df.drop("Summary", axis=1, inplace=True) #löschen der Spalte Summary #axis 1 ist column und axis 0 ist row?
# 
movies_df.tail()
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
#             Gross Release Date      Genre  Runtime  Rating  Rating Count  \
# 611  1.062000e+09   2019-06-11  Animation    100.0     NaN           NaN
# 612  7.594000e+08   2019-07-13   Thriller    136.0     NaN           NaN
# 613  1.632000e+09   2019-07-09      Drama    118.0     NaN           NaN
# 614  2.796000e+09   2019-04-22     Action    181.0     NaN           NaN
# 615           NaN          NaN        NaN      NaN     NaN           NaN
#
#     Summary
# 611     NaN
# 612     NaN
# 613     NaN
# ...

# %%
movies_df.columns = movies_df.columns.str.lower()
movies_df.head()
movies_df.rename(columns={'mpaa rating':'mpaa_rating'})
movies_df.rename(columns={'release date':'release_date'})

movies_df.head()

movies_df.fillna({"rating":movies_df["rating"].median()},inplace=True) # Marcs Lösung
movies_df.head()
# Out:
#    movieid                       title mpaa rating      budget        gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   release date    genre  runtime  rating  rating count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %% [markdown]
# ## Duplikate finden

# %%
#movies_df[movies_df["title"].duplicate(keep = False)] #Marcs Code

# %% [markdown]
# ## String to Integer

# %%
movies_df["budget"]
#movies_df.drop(movies_df.index[-1], axis=0, inplace=True)
#movies_df.iloc[-1:] #zeigt letzte Zeile an
# Out:
# 0        7500000.0
# 1        7500000.0
# 2       13000000.0
# 3       14000000.0
# 4       15000000.0
#           ...
# 611    200000000.0
# 612    200000000.0
# 613    250000000.0
# 614    356000000.0
# 615            NaN
# Name: budget, Length: 616, dtype: float64

# %% [markdown]
# Date

# %%
movies_df.rename(columns={'release date':'release_date'})
# Out:
#      movieid                                  title mpaa rating       budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
#movies_df["release_date"] = pd.to_datetime(movies_df["release_date"]) #funktioniert nicht
#movies_df

# %%
movies_df.rename(columns={'mpaa rating':'mpaa_rating'},inplace=True) #inplace true is important!!!
movies_df.rename(columns={'release date':'release_date'},inplace=True)
movies_df
# Out:
#      movieid                                  title mpaa_rating       budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %% [markdown]
# Rating count umbenennen und die leeren Stellen mit dem MEAN auffüllen

# %%
movies_df.rename(columns={'rating count':'rating_count'},inplace=True)
movies_df.fillna({"rating_count":movies_df["rating_count"].median()},inplace=True) # Marcs Lösung

movies_df.tail()
# Out:
#      movieid                                  title mpaa_rating       budget  \
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
#             gross release_date      genre  runtime  rating  rating_count  \
# 611  1.062000e+09   2019-06-11  Animation    100.0     6.9      240347.5
# 612  7.594000e+08   2019-07-13   Thriller    136.0     6.9      240347.5
# 613  1.632000e+09   2019-07-09      Drama    118.0     6.9      240347.5
# 614  2.796000e+09   2019-04-22     Action    181.0     6.9      240347.5
# 615           NaN          NaN        NaN      NaN     6.9      240347.5
#
#     summary
# 611     NaN
# 612     NaN
# 613     NaN
# ...

# %% [markdown]
# ### Budget und Gross  in integer umwandeln

# %%
movies_df.drop(movies_df.index[-1], axis=0, inplace=True)

# %%
movies_df.dtypes
# Out:
# movieid           int64
# title            object
# mpaa_rating      object
# budget          float64
# gross           float64
# release_date     object
# genre            object
# runtime         float64
# rating          float64
# rating_count    float64
# summary          object
# dtype: object

# %% [markdown]
# Datum umwandeln

# %% [markdown]
# pandas.to_datetime(arg, errors='raise', dayfirst=False, yearfirst=False, utc=False, format=None, exact=<no_default>, unit=None, infer_datetime_format=<no_default>, origin='unix', cache=True)

# %%
movies_df["release_date"] = pd.to_datetime(movies_df["release_date"]) # wichtig ist das pd!!!! pd.to_datetime!!
movies_df.dtypes
# Out:
# movieid                  int64
# title                   object
# mpaa_rating             object
# budget                 float64
# gross                  float64
# release_date    datetime64[ns]
# genre                   object
# runtime                float64
# rating                 float64
# rating_count           float64
# summary                 object
# dtype: object

# %%
movies_df.tail()
# Out:
#      movieid                                  title mpaa_rating       budget  \
# 610      611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
#
#             gross release_date      genre  runtime  rating  rating_count  \
# 610  3.859000e+08   2019-05-13  Adventure    132.0     6.9      240347.5
# 611  1.062000e+09   2019-06-11  Animation    100.0     6.9      240347.5
# 612  7.594000e+08   2019-07-13   Thriller    136.0     6.9      240347.5
# 613  1.632000e+09   2019-07-09      Drama    118.0     6.9      240347.5
# 614  2.796000e+09   2019-04-22     Action    181.0     6.9      240347.5
#
#     summary
# 610     NaN
# 611     NaN
# 612     NaN
# ...

# %% [markdown]
# Aufgabe 3
#
# show the count of Animation movies with more than 7 in Rating (use the shape() method)

# %%
movies_df["genre"].value_counts()
#movies_df["runtime"].value_counts()
# Out:
# genre
# Action             110
# Comedy              99
# Animation           87
# Drama               66
# Thriller            41
# Science Fiction     37
# Adventure           30
# Family              29
# Romance             28
# Fantasy             27
# Crime               17
# Horror              14
# Mystery             11
# War                  9
# Western              6
# History              4
# Name: count, dtype: int64

# %% [markdown]
# Exercise: show the top 5 movies based on Budget

# %%
#Filme die mehr als 180 Minuten Spielzeit haben
movies_df[movies_df["runtime"] > 180]

# Beispiel: pandas intro Emily:
# connect two conditions with |
# pets[(() & ()) | ()]
# pets[(pets["desexed"] == True) | (pets["animal"] == "cat")]
# pets[((pets["desexed"] == False) & (pets["babies"] == 0)) | (pets["animal"] == "cat")]

movies_df[(movies_df["rating"] < 8 ) & (movies_df["genre"] == "History")]
# Out:
#      movieid                title mpaa_rating       budget        gross  \
# 180      181  Shakespeare in Love           R   25000000.0  289317794.0
# 232      233          The Patriot           R  110000000.0  215294342.0
# 458      459              Lincoln       PG-13   65000000.0  275293450.0
#
#     release_date    genre  runtime  rating  rating_count  \
# 180   1998-12-11  History    122.0     7.1      203939.0
# 232   2000-06-28  History    165.0     7.2      241120.0
# 458   2012-11-09  History    149.0     7.3      232227.0
#
#                                                summary
# 180  A young Shakespeare, out of ideas and short of...
# 232  Peaceful farmer Benjamin Martin is driven to l...
# 458  As the American Civil War continues to rage, A...

# %% [markdown]
# pandas.DataFrame.nlargest
# DataFrame.nlargest(n, columns, keep='first')

# %%
#Ich ändere nun etwas 
movies_df[(movies_df["rating"] < 6 ) & (movies_df["genre"] == "Action")]
# Out:
#      movieid                                   title mpaa_rating       budget  \
# 33        34                         Another 48 Hrs.           R   38000000.0
# 109      110                          The Specialist           R   45000000.0
# 137      138                          Batman Forever       PG-13  100000000.0
# 325      326                          Fantastic Four       PG-13  100000000.0
# 366      367  Fantastic 4: Rise of the Silver Surfer          PG  130000000.0
# 412      413             G.I. Joe: The Rise of Cobra       PG-13  175000000.0
# 501      502            Teenage Mutant Ninja Turtles       PG-13  125000000.0
#
#            gross release_date   genre  runtime  rating  rating_count  \
# 33   153518974.0   1990-06-08  Action     95.0     5.9       36103.0
# 109  170362582.0   1994-10-07  Action    110.0     5.6       59371.0
# 137  336529144.0   1995-06-16  Action    121.0     5.4      224254.0
# ...

# %%
define=movies_df[(movies_df["rating"] < 6 ) & (movies_df["genre"] == "Action")]
define
# Out:
#      movieid                                   title mpaa_rating       budget  \
# 33        34                         Another 48 Hrs.           R   38000000.0
# 109      110                          The Specialist           R   45000000.0
# 137      138                          Batman Forever       PG-13  100000000.0
# 325      326                          Fantastic Four       PG-13  100000000.0
# 366      367  Fantastic 4: Rise of the Silver Surfer          PG  130000000.0
# 412      413             G.I. Joe: The Rise of Cobra       PG-13  175000000.0
# 501      502            Teenage Mutant Ninja Turtles       PG-13  125000000.0
#
#            gross release_date   genre  runtime  rating  rating_count  \
# 33   153518974.0   1990-06-08  Action     95.0     5.9       36103.0
# 109  170362582.0   1994-10-07  Action    110.0     5.6       59371.0
# 137  336529144.0   1995-06-16  Action    121.0     5.4      224254.0
# ...

# %% [markdown]
# ## show the top 5 movies based on Budget

# %%
#define=movies_df[(movies_df["rating"] < 6 ) & (movies_df["genre"] == "Action")]

# %% [markdown]
# dataframe.nlargest(n, columns, keep)

# %%
#topfive= movies_df["budget"].nlargest(5,["budget"],all)
#topfive
#movies[(movies["genre"]=="Comedy")].nlargest(5,["rating"])

topfive = movies_df["budget"].nlargest(5)

topfive

topfive3 = movies_df.nlargest(5, "budget")[["title", "budget"]]
topfive3
# Out:
#                                            title       budget
# 594                       Avengers: Infinity War  400000000.0
# 454  Pirates of the Caribbean: On Stranger Tides  380000000.0
# 614                            Avengers: Endgame  356000000.0
# 574                     Star Wars: The Last Jedi  317000000.0
# 375     Pirates of the Caribbean: At World's End  300000000.0

# %%
topfive2 = movies_df.nlargest(5, "budget")
topfive2[["title", "budget"]]
# Out:
#                                            title       budget
# 594                       Avengers: Infinity War  400000000.0
# 454  Pirates of the Caribbean: On Stranger Tides  380000000.0
# 614                            Avengers: Endgame  356000000.0
# 574                     Star Wars: The Last Jedi  317000000.0
# 375     Pirates of the Caribbean: At World's End  300000000.0

# %%
#show the top 5 Comedy movies by Rating

topfive3 = movies_df.nlargest(5, "rating")[["title", "rating"]]
topfive3
# Out:
#                                              title  rating
# 393                                The Dark Knight     9.0
# 83                                Schindler's List     8.9
# 98                               Jurassic Park III     8.9
# 99                                    Pulp Fiction     8.9
# 287  The Lord of the Rings: The Return of the King     8.9

# %%
#bestcomedy= movies_df.nlargest[(5, "budget")[["title", "budget"]] & (movies_df["genre"] == "Comedy")]

# %%
bestcomedy = movies_df[movies_df["genre"] == "Comedy"].nlargest(5, "rating")[["title", "rating"]]
bestcomedy
# Out:
#                     title  rating
# 111          Forrest Gump     8.8
# 185       The Truman Show     8.1
# 80          Groundhog Day     8.0
# 254        Monsters, Inc.     8.0
# 40   Fried Green Tomatoes     7.7

# %%
# Filter stezen:
# movies_df["genre"] == "Comedy": Dies filtert die Zeilen, bei denen die Spalte "genre" den Wert "Comedy" hat.
