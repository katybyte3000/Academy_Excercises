# %% [markdown]
# ## Wiederholung Modul 01 Sprint 4

# %% [markdown]
# ### Data Wrangling

# %%
import pandas as pd
import numpy as np

movies_df = pd.read_csv("movies_2.csv" ) # Gathering data
movies_df.head(3) # head und tail Zeigen Anfang und Ende einer Tabelle an
movies_df.info
# Out:
# <bound method DataFrame.info of      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %% [markdown]
# ### Find missing Values - 2 Schreibweisen

# %%
movies_df["Rating"].isna().value_counts() # kurzer Befehle
missing_values = movies_df["Rating"].isna().value_counts() # dasselbe in etwas ausführlicheren Form
print(f"Anzahl der fehlenden Werte (NaN): {missing_values[True]}")
print(f"Anzahl der vorhandenen Werte: {missing_values[False]}")
# Out:
# Anzahl der fehlenden Werte (NaN): 108
# Anzahl der vorhandenen Werte: 508

# %% [markdown]
# ### Fillna Methode:

# %% [markdown]
# ### a) Mit 2 Schritten> erst Median dann Fillna

# %% [markdown]
# ### b) 1 Schritt mit neuer Variable

# %% [markdown]
# ### c) Fillna mit inplace True- warnt aber

# %%
#a) Median dann Fillna

#medianrating = movies_df['Rating'].median() #ermittelt den Median
#medianrating

#fillnamovies = movies_df["Rating"].fillna(medianrating)
#fillnamovies.tail(3)

# %%
# fillnamovieszwei = movies_df["Rating"].fillna(movies_df['Rating'].median())
# fillnamovieszwei
# fillnamovieszwei.tail(3)

# In einem Schritt aber mit neuer Variable:
#fillnamovieszwei = movies_df["Rating"].fillna(movies_df['Rating'].median())

# c)behalten der Variable movies_df:
movies_df["Rating"].fillna(movies_df['Rating'].median(), inplace=True)

movies_df.tail(3) 


# um warnung zu Vermeiden gibts eine Methode um inplace True 
# genauer zu beschreiben: 
# movies_df["Rating"] = movies_df["Rating"].fillna(movies_df['Rating'].median())
# Out:
# C:\Users\cumdi\AppData\Local\Temp\ipykernel_9188\121760200.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   movies_df["Rating"].fillna(movies_df['Rating'].median(), inplace=True)
#      MovieID              Title MPAA Rating       Budget         Gross  \
# 613      614      The Lion King          PG  250000000.0  1.632000e+09
# 614      615  Avengers: Endgame       PG-13  356000000.0  2.796000e+09
# 615        0                NaN         NaN          NaN           NaN
#
# ...

# %% [markdown]
# letzte Zeile löschen:

# %%
#movies_df(index=615).drop(inplace = True)

# Zeile löschen: df.drop(['ID-123', 'ID-707'], axis=0) #Beispiel aus dem Netz

  
#movies_df.drop(index = 615) # löscht letzte Zeile

# %%
movies_df.tail(3)

movies_df[600:]
# Out:
#      MovieID                                       Title MPAA Rating  \
# 600      601                   The Secret Life of Pets 2          PG
# 601      602               Once Upon a Time in Hollywood           R
# 602      603           The LEGO Movie 2: The Second Part          PG
# 603      604                                     Shazam!       PG-13
# 604      605  How to Train Your Dragon: The Hidden World          PG
# 605      606                   Pokemon Detective Pikachu          PG
# 606      607                   Spider-Man: Far from Home       PG-13
# 607      608                                       Dumbo          PG
# 608      609                              Captain Marvel       PG-13
# 609      610                                     Aladdin          PG
# 610      611              Godzilla: King of the Monsters       PG-13
# 611      612                                 Toy Story 4           G
# 612      613       Fast & Furious Presents: Hobbs & Shaw       PG-13
# ...
